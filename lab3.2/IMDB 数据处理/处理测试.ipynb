# %%
import pandas as pd

data_m = pd.read_csv(
    filepath_or_buffer='/Users/fox/Library/CloudStorage/OneDrive-PetertheGreatSt.PetersburgPolytechnicalUniversity/СПБПУ/3 курс/6 семестр/СУБД/资料/DataSet/data_actresses.list.txt',
    header=0,
    sep='\t'
)
data_m.columns = ['name', 't1', 't2', 't3']

# %%
data_m.head()
# Out:
#                             name  \
# 0  Steff, Stefanie Oxmann Mcgaha
# 1                            NaN
# 2                       $haniqua
# 3                            NaN
# 4                            NaN
#
#                                                   t1  \
# 0  Night of the Demons (2009)  (uncredited)  [Got...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                   t2  \
# 0                                                NaN
# 1                                                NaN
# 2  Please Like Me (2013) {All You Can Eat (#1.4)}...
# 3                                                NaN
# 4                                                NaN
#
#                                                   t3
# 0                                                NaN
# 1  The Bad Lieutenant: Port of Call - New Orleans...
# 2                                                NaN
# 3  Please Like Me (2013) {French Toast (#1.2)}  [...
# 4  Please Like Me (2013) {Horrible Sandwiches (#1...

# %%
data_m['t1'].fillna(value='', inplace=True)
data_m['t2'].fillna(value='', inplace=True)
data_m['t3'].fillna(value='', inplace=True)

moive_list = data_m['t1'] + data_m['t2'] + data_m['t3']

data_m = pd.concat([data_m['name'], moive_list], axis=1)
data_m.columns = ['name', 'title_mix']

# %%
data_m
# Out:
#                                    name  \
# 0         Steff, Stefanie Oxmann Mcgaha
# 1                                   NaN
# 2                              $haniqua
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 12674011         ��r�ard�ttir, Steinunn
# 12674012         ��r�ard�ttir, The�d�ra
# 12674013          ��r�ard�ttir, �l�f A.
# 12674014         ��r�lfsd�ttir, Krist�n
# 12674015                  � R�gvu, Rosa
#
#                                                   title_mix
# 0         Night of the Demons (2009)  (uncredited)  [Got...
# 1         The Bad Lieutenant: Port of Call - New Orleans...
# 2         Please Like Me (2013) {All You Can Eat (#1.4)}...
# 3         Please Like Me (2013) {French Toast (#1.2)}  [...
# 4         Please Like Me (2013) {Horrible Sandwiches (#1...
# ...                                                     ...
# 12674011                        Svartur � leik (2012)  <48>
# 12674012    ��al fe�ranna (1980)  [Kona laxvei�imans]  <10>
# 12674013                      �ram�taskaup 2004 (2004) (TV)
# 12674014         Einkal�f (1995)  [Foreldrar � fundi]  <74>
# 12674015      Bye Bye Blue Bird (1999)  [Pensionatv�rtinde]
#
# [12674016 rows x 2 columns]

# %%
import numpy as np
import re

# %%
data_m = data_m.iloc[:1000, :]

# %%
name_title = []
for col in data_m.values:
    if (col[0] is not np.nan):
        names = col[0]
        name_list = names.split(', ')
        

    for this_name in name_list:

        title_mix = col[1]
        title = None
        year = None
        series_name = None  # 系列名称： {}
        character_name = None  # 角色名称

        title = re.search(r'^[^\(\{\[]*', title_mix)
        if title is not None:
            title = str(title.group()[:-1])

        year = re.search(r'(?!=\({1})[\d]{4}(?!=\){1})', title_mix)
        if year is not None:
            year = int(year.group())

        series_name =  re.search(r'\{(.*?)\}', title_mix)
        if series_name is not None:
            series_name = str(series_name.group()[1:-1])

        character_name =  re.search(r'\[(.*?)\]', title_mix)
        if character_name is not None:
            character_name = str(character_name.group()[1:-1])
        # name_title.append([this_name, title, series_name, year, character_name])
        # name_title.append([this_name, [title, series_name, year, character_name]])
        rols = pd.DataFrame([[title, series_name, year, character_name]], 
                            columns=['title', 'series name', 'year', 'character name'])

        name_title.append([this_name, rols])

# %%
name_title = pd.DataFrame(name_title, columns=['name', 'rols'])
name_title.sort_values(by='name', inplace=True)
name_title.reset_index(drop=True, inplace=True)
name_title.head(20)
# Out:
#                  name                                               rols
# 0                              title series name  year character name...
# 1            $haniqua              title             series name  yea...
# 2            $haniqua              title          series name  year  ...
# 3            $haniqua              title                 series name ...
# 4            $haniqua              title                      series ...
# 5            $haniqua              title                 series name ...
# 6            $haniqua              title          series name  year  ...
# 7            & Ashour       title   series name  year        characte...
# 8            & Ashour               title series name  year        ch...
# 9            & Ashour       title   series name  year               c...
# 10           & Ashour                      title series name  year  c...
# 11           & Ashour          title series name  year character name...
# 12           & Ashour                title series name  year  charact...
# 13           & Ashour               title series name  year  characte...
# 14           & Ashour               title series name  year  characte...
# 15          & Company                        title series name  year ...
# 16      &Aacutelvarez       title series name  year character name
# 0 ...
# 17  ' Betty' Strohfus                                                ...
# 18     ' Scotty'Gough                                                ...
# 19         '67 Impala            title           series name  year ch...

# %%
name_title.loc[2]['name']
# Out:
# '$haniqua'

# %%
name = None
tmp_list_rols = []
list_name_rols = []
for i in range(name_title.shape[0]):
    if name == name_title.loc[i]['name']:
        tmp_list_rols.append(name_title.loc[i]['rols'])
    else:
        if name is not None:
            list_name_rols.append([name, tmp_list_rols])
        name = name_title.loc[i]['name']
        tmp_list_rols = []
        tmp_list_rols.append(name_title.loc[i]['rols'])

# %%
name = None
tmp_df_rols = []
list_name_rols = []
for i in range(name_title.shape[0]):
    if name == name_title.loc[i]['name']:
        tmp_df_rols = pd.concat([tmp_df_rols, name_title.loc[i]['rols']])
        # print('要拼接的：\n', name_title.loc[i]['rols'])
        # print('拼接后的：\n', tmp_df_rols)
        # print('\n==========================================\n\n')
    else:
        if name is not None:
            list_name_rols.append([name, tmp_df_rols])

            # if name == '$haniqua':
            #     print(tmp_df_rols)

        name = name_title.loc[i]['name']
        tmp_df_rols = name_title.loc[i]['rols']
# Out:
#             title                      series name  year       character name
# 0  Please Like Me           All You Can Eat (#1.4)  2013  $haniqua the Rabbit
# 0  Please Like Me              French Toast (#1.2)  2013  $haniqua the Rabbit
# 0  Please Like Me       Horrible Sandwiches (#1.6)  2013  $haniqua the Rabbit
# 0  Please Like Me  Portuguese Custard Tarts (#1.3)  2013  $haniqua the Rabbit
# 0  Please Like Me       Rhubarb and Custard (#1.1)  2013  $haniqua the Rabbit
# 0  Please Like Me              Spanish Eggs (#1.5)  2013  $haniqua the Rabbit

# %%
list_name_rols
# Out:
# [['',
#           title series name  year character name
#   0  Naya Samaj        None  1976           None],
#  ['$haniqua',
#               title             series name  year       character name
#   0  Please Like Me  All You Can Eat (#1.4)  2013  $haniqua the Rabbit],
#  ['& Ashour',
#        title   series name  year        character name
#   0  Variety  (1937-06-05)  1936  Themselves - Dancers],
#  ['& Company',
#                         title series name  year character name
#   0  This American Life Live!        None  2012        Dancers],
#  ['&Aacutelvarez',
#        title series name  year character name
#   0  M�mesis        None  2012          Sonia],
#  ["' Betty' Strohfus",
#                                                  title series name  year  \
#   0  Broads & Bombers; a Wartime Experiment in Manp...        None  2016
#
#     character name
#   0        Herself  ],
#  ["' Scotty'Gough",
#                                                  title series name  year  \
#   0  Broads & Bombers; a Wartime Experiment in Manp...        None  2016
#
#     character name
#   0        Herself  ],
#  ["'67 Impala",
#             title           series name  year character name
#   0  Supernatural  Nightshifter (#2.12)  2005        Herself],
#  ["'Barry' Vincent",
#                                                  title series name  year  \
#   0  Broads & Bombers; a Wartime Experiment in Manp...        None  2016
#
#     character name
#   0        Herself  ],
#  ["'Dot' Lewis",
#                                                  title series name  year  \
#   0  Broads & Bombers; a Wartime Experiment in Manp...        None  2016
#
#     character name
#   0        Herself  ],
#  ["'Electric Nana'. V�zquez",
#              title   series name  year character name
#   0  El hormiguero  (2011-03-23)  2006        Herself],
#  ["'Gaby' Goff",
#                        title series name  year character name
#   0  Welcome to My Darkside!        None  2009        Herself],
#  ["'J.T.' Thompson",
#           title series name  year character name
#   0  The Shrink        None  None          Janet],
#  ["'La Mueque'",
#             title series name  year character name
#   0  Los tarantos        None  1963        Cantaor],
#  ["'La Tata' Castro",
#                 title series name  year character name
#   0  La granja tolima        None  2004        Herself],
#  ["'La Veneno'",
#                         title series name  year character name
#   0  La venganza de la Veneno        None  1997           None],
#  ["'Memory' Johnson",
#               title series name  year character name
#   0  Shining Spirit        None  2017         Memory],
#  ["'Mickey''Brown",
#                                                  title series name  year  \
#   0  Broads & Bombers; a Wartime Experiment in Manp...        None  2016
#
#     character name
#   0        Herself  ],
#  ["'Misschiviss",
#                                      title series name  year character name
#   0  Portland Hip Hop: Lifting as We Climb        None  2016        Herself],
#  ["'Noble Julz'Hamilton",
#              title series name  year character name
#   0  Between Women      (#1.9)  2011   Brooke Scott],
#  ["'Pouty Dog' Bergquist",
#                            title series name  year character name
#   0  The Chronic Adventure Story        None  2018   Pavlov's Dog],
#  ["'Pretty Lyon'Cruel",
#                     title series name  year character name
#   0  Waiting 4 Mr. Wright        None  2015         Morgan],
#  ["'Rosalie' Sadlik",
#                     title series name  year character name
#   0  Welcome to Slab City        None  2012        Herself],
#  ["'Rovel' Torres",
#                                       title  \
#   0  The Tonight Show Starring Jimmy Fallon
#
#                                     series name  year             character name
#   0  Ice T/Andrew Rannells/Lupe Fiasco (#2.105)  2014  Herself - Musical Support  ],
#  ["'Skittles' Greene",
#             title series name  year character name
#   0  BoS: Knights        None  2019       8 (2019)],
#  ["'Tay' Listenbee",
#                title series name  year character name
#   0  South of Sanity        None  2016    Frita Clark],
#  ["'The Diva' Durham",
#                title series name  year character name
#   0  Magazine Issues        None  2016    Mrs. Peters],
#  ["'The Queen' Williams",
#                     title series name  year character name
#   0  Welcome to Slab City        None  2012        Herself],
#  ["'Tush' Harris",
#                      title series name  year character name
#   0  Blood of the Tribades        None  2016  The Great One],
#  ["'Twinkie' Bird",
#           title                                     series name  year  \
#   0  Casting Qs  An Interview with Tracy 'Twinkie' Byrd (#2.14)  2010
#
#     character name
#   0        Herself  ],
#  ["'s Gravemade",
#            title series name  year character name
#   0  Toxhibition        None  2011         Friend],
#  ["'sGravemade",
#                            title series name  year character name
#   0  Three Is the Perfect Number        None  2017           Lois],
#  ["'t Hart",
#                 title series name  year  character name
#   0  De nieuwe moeder        None  1996  Vrouw in trein],
#  ["'t Jolle",
#     title                    series name  year          character name
#   0  Aspe  De architect - Deel 1 (#6.12)  2004  Juliette De Baetselier],
#  ["'t Seyen",
#                     title series name  year         character name
#   0  De moedige bruidegom        None  1952  De moeder van Tinneke],
#  ["'ya",
#               title series name  year character name
#   0  Fillet of Soul        None  2001           None],
#  ['-',
#               title series name  year character name
#   0  The Oats Movie        None  2017     Random Pig],
#  ['-Birch',
#                                                  title series name  year  \
#   0  The Story of Peter Pendragon: Knight Out - Cha...        None  2016
#
#     character name
#   0     Clementine  ],
#  ['-Davis',
#                                           title series name  year character name
#   0  American Soundtrack: Rhythm, Love and Soul        None  2003        Herself],
#  ['-Durell',
#                    title series name  year character name
#   0  In Sheep's Clothing        None  2016         Lawyer],
#  ['-Gradowska',
#                       title series name  year character name
#   0  Who are the WWP Women?        None  2015        Herself],
#  ['-James',
#               title series name  year   character name
#   0  Social Suicide        None  2015  Baked Bean Girl],
#  ['-Kov�g�',
#              title series name  year character name
#   0  L�thatatlanul        None  2017           Luca],
#  ['-Ward',
#         title series name  year character name
#   0  Sea Wolf        None  2018  Sailor's wife],
#  ['-Weigl',
#      title series name  year character name
#   0  Ropes        None  2006           Wife],
#  ['-fox',
#            title series name  year character name
#   0  Love Online        None  2014           None],
#  ['.',
#                title series name  year character name
#   0  Madam President        None  2016          Samar],
#  ['.C.',
#             title series name  year character name
#   0  Snake Ladies        None  2015     Chief Cook],
#  ['.Heather',
#             title series name  year character name
#   0  Talk with Me        None  2013       Georgina],
#  ['1',
#                                                  title series name  year  \
#   0  Hustler's Untrue Hollywood Stories: Angelina v...        None  2009
#
#     character name
#   0           None  ],
#  ['10 Soprano',
#                 title series name  year character name
#   0  Davno ne videlis     (#1.13)  2011     Themselves],
#  ['103',
#        title series name  year character name
#   0  Anna II        None  2005        Anna II],
#  ['10X',
#                    title                      series name  year  \
#   0  American Experience  Malcolm X: Make It Plain (#6.5)  1988
#
#                 character name
#   0  Herself - Nation of Islam  ],
#  ['11',
#                       title series name  year character name
#   0  Meus Pr�mios Nick 2012        None  2012     Themselves],
#  ['12 Elite Girls',
#                     title series name  year character name
#   0  Holzapfel wei� alles        None  1932         T�nzer],
#  ['18',
#                                         title series name  year character name
#   0  Lightspeed University: Cheerleader Power        None  2005           None],
#  ['1934 Goldwyn Girls',
#             title series name  year character name
#   0  Kid Millions        None  1934     Show Girls],
#  ['1988 Montclair Squad',
#             title series name  year character name
#   0  Monster High        None  1989   Cheerleaders],
#  ['2',
#       title series name  year character name
#   0  Donoma        None  2010            Ma�],
#  ['2 Shoes',
#             title               series name  year            character name
#   0  The X Factor  Judges' Houses 2 (#8.11)  2004  Themselves - Contestants],
#  ["2's Country",
#                     title               series name  year  \
#   0  Britain's Got Talent  2013: Auditions 1 (#7.1)  2007
#
#                character name
#   0  Themselves - Contestants  ],
#  ['2-Ply',
#                          title series name  year character name
#   0  Nice Shoes... Wanna Fuck?        None  2012      Paparazzo],
#  ['20 Wienerinnen',
#                       title series name  year character name
#   0  Heut' kommt's drauf an        None  1933           None],
#  ['2004 Buffalo Jills Cheerleaders',
#                                             title series name  year  \
#   0  Buffalo Jill's on DVD 2004: Swimsuit Edition        None  2004
#
#     character name
#   0     Themselves  ],
#  ['21 Japonesas',
#                     title series name  year character name
#   0  Sigue, sigue Pl�stic      (#1.4)  1991     Themselves],
#  ['2Hypa',
#                          title series name  year            character name
#   0  Move Like Michael Jackson      (#1.6)  2009  Themselves - Contestants],
#  ["2Squar'd",
#             title             series name  year           character name
#   0  The X Factor  Judges' Home #2 (#1.8)  2011  Themselves - Contestant],
#  ['2Yoon',
#            title series name  year      character name
#   0  Weekly Idol     (#1.80)  2011  Themselves - Guest],
#  ['2ne1',
#             title series name  year character name
#   0  The Bachelor     (#18.4)  2002     Themselves],
#  ['3 Little Women',
#                                        title series name  year character name
#   0  The 16th Annual Soul Train Music Awards        None  2002     Themselves],
#  ['3-Stah',
#                     title              series name  year  \
#   0  Pilipinas Got Talent  Audition Day 12 (#3.12)  2010
#
#               character name
#   0  Themselves - Auditionee  ],
#  ['314',
#                    title series name  year character name
#   0  Infernal Restraints     Ingenue  2006           None],
#  ['34D',
#              title series name  year      character name
#   0  Fahrenheit 69        None  2004  Liberated Iraqi #2],
#  ['38G',
#                 title          series name  year character name
#   0  Extreme Naturals  Double Take (#2.21)  2006           None],
#  ['3am',
#                     title series name  year            character name
#   0  Cut N' Dry Talent TV      (#1.5)  2014  Themselves - Music Video],
#  ['3d',
#            title                                series name  year  \
#   0  Star Search  The One with Living Single Star Kim Coles  1983
#
#                  character name
#   0  Themselves - Young Dancers  ],
#  ['4 Ever',
#                title series name  year character name
#   0  Young and Tight        None  2001           None],
#  ['4 Non Blondes',
#                               title   series name  year  \
#   0  Late Show with David Letterman  (1994-01-04)  1993
#
#                  character name
#   0  Themselves - Musical Guest  ],
#  ['40 B.A.R.R.S.',
#            title                series name  year character name
#   0  RapFix Live  Troy Ave, Wu-Tang (#4.35)  2010        Herself],
#  ['412',
#       title  series name  year character name
#   0  TopGrl  Definitions  2009           None],
#  ['4Magic',
#                   title               series name  year character name
#   0  X Factor: Bulgaria  Week 2: Halloween (#5.2)  2013     Themselves],
#  ['4Minute',
#            title series name  year character name
#   0  Weekly Idol     (#1.87)  2011     Themselves],
#  ['4th Impact',
#                title           series name  year          character name
#   0  The Xtra Factor  Live Show 1 (#12.15)  2004  Themselves - Featuring],
#  ['62',
#              title       series name  year character name
#   0  House of Gord  Orgasming Cocoon  2001           None],
#  ['69',
#       title series name  year character name
#   0  Ib�ria        None  2007         A Muse],
#  ['7',
#                                                title series name  year  \
#   0  Gendernauts - Eine Reise durch die Geschlechter        None  1999
#
#     character name
#   0           None  ],
#  ['7 Year Bitch',
#                    title series name  year    character name
#   0  Toast with the Gods        None  1995  The Lotus Eaters],
#  ['702',
#            title series name  year character name
#   0  Beep Me 911        None  1998  Plastic dolls],
#  ['9',
#                  title series name  year character name
#   0  Domina's Daydream        None  2001           None],
#  ['912',
#                              title series name  year character name
#   0  Supertight Bondage Challenges        None  2010           None],
#  ['95',
#             title series name  year character name
#   0  Amors baller        None  2011     Jentelaget],
#  ['@You',
#                                  title series name  year character name
#   0  Itazura kaseifu: Ijimete shibatte        None  2007           None],
#  ['A',
#              title series name  year          character name
#   0  De foute quiz      (#1.7)  2007  Herself - Team Captain],
#  ['A qui Avec Gabriel',
#                title series name  year character name
#   0  April's Shadows        None  2013        Herself],
#  ["A'Alitaleb",
#          title series name  year character name
#   0  Amor-Love        None  2002          Zaida],
#  ["A'Beckett",
#                 title series name  year character name
#   0  Rover Makes Good        None  1952    Aunt Jennie],
#  ["A'Costa",
#                  title series name  year character name
#   0  The Mints of Hell        None  1919           Tete],
#  ["A'Court",
#                 title series name  year character name
#   0  Shortland Street    (#18.76)  1992   Helen Carson],
#  ["A'Dair",
#               title series name  year  character name
#   0  Sierra Spirits        None  2009  Saloon Lady #2],
#  ["A'Deane",
#               title                         series name  year character name
#   0  Family Affairs  Tony Cultivates Some Swedes (#1.7)  1949         Marion],
#  ["A'Hern",
#                title series name  year character name
#   0  Out of the Blue    (#1.120)  2008    Lucia Jones],
#  ["A'Kimmi",
#                 title series name  year       character name
#   0  King of the Game        None  2014  Truck Stop Strutter],
#  ["A'Leur",
#                               title series name  year character name
#   0  Brew City Bombshells Burlesque        None  2011  Aurora A'Leur],
#  ["A'Lex",
#                title                    series name  year    character name
#   0  Class N Session  "Meet Kaitlyn Johnson" (#1.1)  2017  Vanessa Hardison],
#  ["A'Moore",
#                       title series name  year character name
#   0  Submerge: Ni're Reborn        None  2015          Ni're],
#  ["A'Shayla",
#                        title                                  series name  year  \
#   0  On the Scene Web Series  You Ain't Called, Texted, Nothing... (#3.3)  2015
#
#     character name
#   0        Herself  ],
#  ["A'Virmond",
#                                                  title series name  year  \
#   0  How to Dance Through Time, Vol III: The Majest...        None  2003
#
#     character name
#   0        Herself  ],
#  ["A'mora",
#                title                    series name  year    character name
#   0  Class N Session  "Meet Kaitlyn Johnson" (#1.1)  2017  Vanessa Hardison],
#  ["A'ngelique",
#                    title series name  year character name
#   0  Pocket Full of Gold        None  2009        Cowgirl],
#  ['A.',
#         title series name  year character name
#   0  Disputas      (#1.7)  2003          Gisel],
#  ['A. Awan',
#              title series name  year character name
#   0  Death Benefit        None  2014      Zoe Valle],
#  ['A. Casares',
#                              title       series name  year character name
#   0  La tierra de las 1000 m�sicas  La balada (#1.4)  1000        Herself],
#  ['A. Guggenheim',
#            title series name  year character name
#   0  After Maiko        None  2015  Sophia Martin],
#  ['A. Ross',
#                     title                    series name  year character name
#   0  Tangents & the Times  Marissa Gets Flustered (#1.4)  2011        Marissa],
#  ['A. Singh',
#                             title   series name  year character name
#   0  Cambala Investigation Agency  Bank Robbery  2008          Nikki],
#  ['A. Sirnaik',
#           title series name  year character name
#   0  Dream Lock        None  2016          Maria],
#  ['A.D.',
#                           title   series name  year           character name
#   0  Last Call with Carson Daly  (2013-10-21)  2002  Herself - Musical guest],
#  ['A.J.',
#                 title                       series name  year  \
#   0  Top star magaz�n  Top star magaz�n 2012/10 (#5.10)  2008
#
#            character name
#   0  Herself (Sexy Model)  ],
#  ['A.J. (VI)',
#                 title series name  year character name
#   0  Manila Exposed 9        None  2008           None],
#  ['A.J. (XVI)',
#               title                   series name  year  \
#   0  Project Runway  The Art of the Matter (#9.6)  2004
#
#                           character name
#   0  Herself - Anya Ayoung Chee's Artist  ],
#  ['A.J. (XVIII)',
#             title          series name  year character name
#   0  Real Orgasms  Ripe Cherry (#1.13)  2006           None],
#  ['A.K.',
#                    title series name  year character name
#   0  XConfessions Vol. 1        None  2013           None],
#  ['A.N.',
#      title series name  year character name
#   0  Naani        None  2016           None],
#  ['A.johnson',
#              title series name  year     character name
#   0  Mariage forc�        None  2015  M�re de la mari�e],
#  ['Aabba',
#                title series name  year character name
#   0  Miss� on miss�?        None  2009       Villager],
#  ['Aabed',
#                                      title series name  year  \
#   0  Paranorma There Is Always a Dark Side        None  2011
#
#                                  character name
#   0  One eyed girl in the Surreal World Segment  ],
#  ['Aabel',
#            title series name  year character name
#   0  Tidsbonanza      (#1.6)  2016        Herself],
#  ['Aaberg',
#                title series name  year character name
#   0  Same Difference        None  2015           None],
#  ['Aaberge',
#      title series name  year character name
#   0  R�det      (#1.1)  2013        Herself],
#  ['Aaboe',
#          title                    series name  year character name
#   0  Bryggeren  12. afsnit, 1884-1887 (#1.12)  1996      Fru K�hle],
#  ['Aabram',
#                                title series name  year character name
#   0  A Glimpse of GOD'S Hand at Work        None  2014        Toddler],
#  ['Aaby',
#                      title series name  year character name
#   0  Sejer - Elskede Poona        None  2003   Karen Krantz],
#  ['Aabye',
#     title                          series name  year character name
#   0   Dag  To bryllup og en begravelse (#3.10)  2010     Damef�tter],
#  ['Aab�',
#             title series name  year character name
#   0  D�rlig kjemi        None  2007    Maren Sofie],
#  ['Aack',
#                                    title series name  year character name
#   0  Satanico Pandemonium: La Sexorcista        None  1975           None],
#  ['Aad',
#                  title series name  year character name
#   0  The Cedar's Tears        None  2010         Thalia],
#  ['Aadams',
#                          title series name  year  character name
#   0  BNP Paribas Showdown 2015        None  2015  Herself - Host],
#  ['Aadhira',
#        title series name  year character name
#   0  Kolanji        None  2017           None],
#  ['Aadi',
#                              title series name  year character name
#   0  Kochavva Paulo Ayyappa Coelho        None  2016         Ambili],
#  ['Aadland',
#                    title series name  year character name
#   0  Death of a Salesman        None  1951           Girl],
#  ['Aadli',
#            title series name  year character name
#   0  Jeans Tonic        None  1984      A student],
#  ['Aadussoo',
#      title series name  year character name
#   0  Klass        None  2007           None],
#  ['Aae',
#                    title          series name  year character name
#   0  �rhundredets vidner  De f�rste teenagere  1998        Herself],
#  ['Aafer',
#               title series name  year character name
#   0  Ik Hartje Oost        None  2014          Sarah],
#  ['Aafif',
#                title series name  year character name
#   0  Hanan Wa Haneen        None  2007          Marwa],
#  ['Abini',
#                              title series name  year character name
#   0  Kochavva Paulo Ayyappa Coelho        None  2016         Ambili],
#  ['Adhama',
#                     title series name  year character name
#   0  Waiting 4 Mr. Wright        None  2015         Morgan],
#  ['Ahed',
#                               title                series name  year  \
#   0  Full Frontal with Samantha Bee  December 19, 2016 (#1.34)  2016
#
#     character name
#   0        Herself  ],
#  ['Alexa',
#                title series name  year character name
#   0  I Need to Pee 7        None  2007           None],
#  ['Alicetogizzelle (II)',
#         title             series name  year character name
#   0  Ensemble  Cut in the Chat (#1.2)  2014      The Woman],
#  ['Alicia',
#                    title                           series name  year  \
#   0  MatthewDieuAllen TV  What Is a Matthew Dieu Allen? (#3.3)  2008
#
#     character name
#   0        Herself  ],
#  ['Aliz V�ndo',
#              title series name  year character name
#   0  L�thatatlanul        None  2017           Luca],
#  ['Amanda',
#           title series name  year character name
#   0  Spidertron        None  2008        Goylgar],
#  ['Anastasia',
#               title series name  year           character name
#   0  Red Like Blood        None  2005  Junkie C - Fourth Story],
#  ['Angel',
#                                   title                            series name  \
#   0  The Time with Matthew & Randy Show  Sacramento, California: Part 2 (#6.2)
#
#      year character name
#   0  2008        Herself  ],
#  ['Anna',
#        title series name  year character name
#   0  Llamada        None  2011           None],
#  ['Annett',
#       title series name  year character name
#   0  Floare        None  2013           None],
#  ['Anouk',
#               title series name  year character name
#   0  Sporty Teens 4        None  2006           None],
#  ['Arla',
#                title series name  year character name
#   0  Miss� on miss�?        None  2009       Villager],
#  ['Aurora',
#                               title series name  year character name
#   0  Brew City Bombshells Burlesque        None  2011  Aurora A'Leur],
#  ['Autumn',
#                                title series name  year character name
#   0  A Glimpse of GOD'S Hand at Work        None  2014        Toddler],
#  ['Aziza',
#                 title series name  year                character name
#   0  Eine andere Liga        None  2005  Fatos - Spielerin FC Schanze],
#  ['Basia',
#                       title                  series name  year character name
#   0  Don't Blame the Koalas  Things That Go Bump (#1.10)  2002      Kate King],
#  ['Beth Chisholm',
#                                                  title series name  year  \
#   0  The Story of Peter Pendragon: Knight Out - Cha...        None  2016
#
#     character name
#   0     Clementine  ],
#  ['Bethan Williams',
#               title series name  year   character name
#   0  Social Suicide        None  2015  Baked Bean Girl],
#  ['Beverly',
#                                                  title series name  year  \
#   0  Tasmanian Devil: The Fast and Furious Life of ...        None  2007
#
#     character name
#   0        Herself  ],
#  ['Bunny',
#               title series name  year character name
#   0  Teeny Splash 3        None  2007           None],
#  ['Camila',
#                            title series name  year character name
#   0  Seventeen Collected Solo 63        None  2013           None],
#  ['Cat',
#                  title series name  year character name
#   0  Domina's Daydream        None  2001           None],
#  ['Chalyn',
#             title                      series name  year  character name
#   0  Lindenstra�e  Ein bisschen Shopping (#1.1482)  1985  Emma Sarikakis],
#  ['Christen',
#                    title series name  year                 character name
#   0  Havet og menneskene        None  1970  Sogner�dsformand H.P. Nielsen],
#  ['Clare Angelini',
#             title series name  year character name
#   0  Talk with Me        None  2013       Georgina],
#  ['College',
#                       title series name  year character name
#   0  Meus Pr�mios Nick 2012        None  2012     Themselves],
#  ['Courtenay',
#                 title series name  year       character name
#   0  King of the Game        None  2014  Truck Stop Strutter],
#  ['Cristina',
#                title   series name  year character name
#   0  Aqu� hay tomate  (2006-10-11)  2003        Herself],
#  ['Crystal',
#                                       title  \
#   0  The Tonight Show Starring Jimmy Fallon
#
#                                     series name  year             character name
#   0  Ice T/Andrew Rannells/Lupe Fiasco (#2.105)  2014  Herself - Musical Support  ],
#  ['Dakota',
#             title                  series name  year character name
#   0  Playboy Plus  Dakota A. in Wildest Dreams  2009        Herself],
#  ['Debora',
#                          title series name  year character name
#   0  Rocco's Intimate Castings        None  2016           None],
#  ['Delphine',
#       title series name  year character name
#   0  Donoma        None  2010            Ma�],
#  ['Derya',
#                    title series name  year character name
#   0  Lesbian Fuck Fest 5        None  2010           None],
#  ['Diamond',
#              title series name  year character name
#   0  Initiations 5        None  2000           None],
#  ['Die',
#                       title series name  year character name
#   0  Heut' kommt's drauf an        None  1933           None],
#  ['Dina',
#                                       title series name  year character name
#   0  Oral Majority 3: The Lust Continues...        None  1987           None],
#  ['Doga',
#                                                 title series name  year  \
#   0  Hercules: The Legendary Journeys - Blond You Out        None  2007
#
#     character name
#   0           None  ],
#  ['Donna',
#                title series name  year character name
#   0  Hello Au Revoir        None  2018           None],
#  ['Dorthy',
#                                                  title series name  year  \
#   0  Broads & Bombers; a Wartime Experiment in Manp...        None  2016
#
#     character name
#   0        Herself  ],
#  ['Edith',
#         title series name  year character name
#   0  Omringet        None  1960           None],
#  ['Eleanor',
#                                                  title series name  year  \
#   0  Broads & Bombers; a Wartime Experiment in Manp...        None  2016
#
#     character name
#   0        Herself  ],
#  ['Elisa',
#             title series name  year character name
#   0  BoS: Knights        None  2019       8 (2019)],
#  ['Elizabeth',
#                                                  title series name  year  \
#   0  Broads & Bombers; a Wartime Experiment in Manp...        None  2016
#
#     character name
#   0        Herself  ],
#  ['Elza',
#                   title       series name  year character name
#   0  Blondi tuli taloon  Umpikuja (#2.28)  1994        Turtzik],
#  ['Erin',
#                       title series name  year character name
#   0  Submerge: Ni're Reborn        None  2015          Ni're],
#  ['Favour Shedrack',
#             title series name  year character name
#   0  Snake Ladies        None  2015     Chief Cook],
#  ['Florence',
#                                        title series name  year character name
#   0  The Truth About Fidel Castro Revolution        None  1959        Herself],
#  ['Galina',
#       title series name  year character name
#   0  Lyderi        None  2013        Herself],
#  ['Get�lio',
#                     title series name  year character name
#   0  A Praia da Sacanagem        None  1985           None],
#  ['Girl',
#                                                  title series name  year  \
#   0  Hustler's Untrue Hollywood Stories: Angelina v...        None  2009
#
#     character name
#   0           None  ],
#  ['Guenaelle',
#              title series name  year     character name
#   0  Mariage forc�        None  2015  M�re de la mari�e],
#  ['Hauk (II)',
#              title series name  year character name
#   0  Bikini Bistro        None  1995  Bistro Patron],
#  ['Hilda',
#                     title series name  year         character name
#   0  De moedige bruidegom        None  1952  De moeder van Tinneke],
#  ['Indiana',
#            title series name  year character name
#   0  Girlfriends        None  2010        Herself],
#  ['Ingrid Bergan',
#             title series name  year character name
#   0  D�rlig kjemi        None  2007    Maren Sofie],
#  ['Ingvild',
#     title                          series name  year character name
#   0   Dag  To bryllup og en begravelse (#3.10)  2010     Damef�tter],
#  ['Isabelle',
#              title series name  year          character name
#   0  De foute quiz      (#1.5)  2007  Herself - Team Captain],
#  ["J'avona",
#       title series name  year character name
#   0  Echoes        None  2010          Jesse],
#  ['Jackie',
#               title series name  year character name
#   0  Rendezvous 17M        None  2005            Mel],
#  ['Jane',
#       title series name  year character name
#   0  Ib�ria        None  2007         A Muse],
#  ['Jardar',
#             title series name  year character name
#   0  Amors baller        None  2011     Jentelaget],
#  ['Jasmin',
#       title           series name  year character name
#   0  C.I.D.  Nanhi Gavah (#1.586)  1998           Tina],
#  ['Jean',
#                 title series name  year character name
#   0  Rover Makes Good        None  1952    Aunt Jennie],
#  ['Jill',
#               title series name  year character name
#   0  Punk Fu Zombie        None  2017       Figurant],
#  ['Johnson. Michelle',
#         title series name  year character name
#   0  Unspoken        None  2014         Lauren],
#  ['Josine',
#                        title series name  year character name
#   0  Il barbiere di Siviglia        None  1992   Mime artists],
#  ['Julie',
#           title series name  year character name
#   0  The Shrink        None  None          Janet],
#  ['Kalpana',
#      title series name  year character name
#   0  Naani        None  2016           None],
#  ['Kasia Lewandowska',
#                       title series name  year character name
#   0  Who are the WWP Women?        None  2015        Herself],
#  ['Kat',
#                  title series name  year character name
#   0  Destined for Pain        None  2002           None],
#  ['Kate (II)',
#               title series name  year character name
#   0  The Oats Movie        None  2017     Random Pig],
#  ['Katherine Bennet',
#            title series name  year character name
#   0  Love Online        None  2014           None],
#  ['Katrina',
#                          title series name  year  character name
#   0  BNP Paribas Showdown 2014        None  2014  Herself - Host],
#  ['Kayleah',
#                                   title                            series name  \
#   0  The Time with Matthew & Randy Show  Sacramento, California: Part 2 (#6.2)
#
#      year character name
#   0  2008        Herself  ],
#  ['Kaytlin',
#                    title                        series name  year character name
#   0  MatthewDieuAllen TV  Enchanted Village: Part 2 (#5.21)  2008        Herself],
#  ['Kim',
#                               title            series name  year character name
#   0  The Story of Matthew & Brandon  LJ's Bday Bash (#1.3)  2014        Herself],
#  ['Kimberly',
#               title      series name  year character name
#   0  Lizzie McGuire  Bunkies (#2.25)  2001    Drama Queen],
#  ['Kisha Emanuel',
#                    title series name  year character name
#   0  In Sheep's Clothing        None  2016         Lawyer],
#  ['Kristy',
#                    title     series name  year character name
#   0  MatthewDieuAllen TV  Kittens (#1.9)  2008        Herself],
#  ['Laura',
#                                                  title series name  year  \
#   0  Emmanuelle the Private Collection: Jesse's Sec...        None  2006
#
#     character name
#   0           Rain  ],
#  ['Lauren',
#            title series name  year character name
#   0  French Kiss        None  2015           Emma],
#  ['Leydia',
#             title series name  year character name
#   0  Satu kecupan        None  2004           None],
#  ['Liisa',
#            title series name  year character name
#   0  The Arbiter        None  2013           None],
#  ['Liv',
#        title series name  year character name
#   0  Sincere        None  2012           None],
#  ['Louise Cameron',
#         title series name  year character name
#   0  Sea Wolf        None  2018  Sailor's wife],
#  ['Lucienne',
#        title   series name  year        character name
#   0  Variety  (1937-06-05)  1936  Themselves - Dancers],
#  ['Lucky',
#         title                                        series name  year  \
#   0  Real Sex  Real Sex 24: Different Strokes/Dirty Words/Foo...  1990
#
#      character name
#   0  Herself - Poet  ],
#  ['Lucy',
#                            title series name  year character name
#   0  The Chronic Adventure Story        None  2018   Pavlov's Dog],
#  ['Mabel',
#                                                  title series name  year  \
#   0  Broads & Bombers; a Wartime Experiment in Manp...        None  2016
#
#     character name
#   0        Herself  ],
#  ['Maia Helene Friise',
#                      title series name  year character name
#   0  Sejer - Elskede Poona        None  2003   Karen Krantz],
#  ['Manjula Rai',
#           title series name  year character name
#   0  Naya Samaj        None  1976           None],
#  ['Mari',
#            title        series name  year character name
#   0  Kelgukoerad  Topeltm�ng (#2.6)  2006           S�de],
#  ['Maria Tereza',
#                 title series name  year character name
#   0  La granja tolima        None  2004        Herself],
#  ['Mariana',
#         title series name  year character name
#   0  Disputas      (#1.7)  2003          Gisel],
#  ['Marieke',
#                      title   series name  year  \
#   0  De wereld draait door  (2013-09-20)  2005
#
#                                     character name
#   0  Herself - Hoofdredacteur VROUW - De Telegraaf  ],
#  ['Marilia',
#            title                 series name  year character name
#   0  Yo quisiera  El primer concierto (#1.3)  2015           None],
#  ['Marissa',
#                  title series name  year character name
#   0  Sweet Mary & Jane        None  2012        Herself],
#  ['Martha',
#        title series name  year character name
#   0  Anna II        None  2005        Anna II],
#  ['Mary',
#              title series name  year      character name
#   0  Fahrenheit 69        None  2004  Liberated Iraqi #2],
#  ['Melanie',
#               title series name  year character name
#   0  Shining Spirit        None  2017         Memory],
#  ['Michele',
#         title             series name  year character name
#   0  Go Girls  Pushing Buttons (#5.4)  2009         Miriam],
#  ['Michelle',
#        title series name  year character name
#   0  M�mesis        None  2012          Sonia],
#  ['Mieke',
#                title series name  year character name
#   0  People in White        None  2011        Herself],
#  ['Mika',
#          title series name  year character name
#   0  Champagne        None  2010        Herself],
#  ['Mira',
#     title                    series name  year          character name
#   0  Aspe  De architect - Deel 1 (#6.12)  2004  Juliette De Baetselier],
#  ['Miriam',
#              title series name  year character name
#   0  Death Benefit        None  2014      Zoe Valle],
#  ['Miss',
#                         title series name  year character name
#   0  Black Tranny Whackers 12        None  2009           None],
#  ['Miss Marsha',
#                                   title series name  year character name
#   0  Challenger: Voices from the Street        None  2016        Herself],
#  ['Moni',
#               title series name  year character name
#   0  Fillet of Soul        None  2001           None],
#  ['Monica Bill Barnes',
#                         title series name  year character name
#   0  This American Life Live!        None  2012        Dancers],
#  ['Mrs.',
#                  title series name  year character name
#   0  The Mints of Hell        None  1919           Tete],
#  ['Myriam',
#            title series name  year character name
#   0  Jeans Tonic        None  1984      A student],
#  ['M�nica',
#             title series name  year character name
#   0  Santo Enredo        None  1995        Chica 1],
#  ['Nancy',
#                         title series name  year                  character name
#   0  A PornDoe Premium XXXmas        None  2016  (story: 'Nancy's X-Mas Treat')],
#  ['Natascha',
#                       title series name  year character name
#   0  Radioresepsjonen p� TV      (#1.2)  2010        Herself],
#  ['Nathalie',
#                  title series name  year character name
#   0  The Cedar's Tears        None  2010         Thalia],
#  ['Nazli Rawwas',
#                title series name  year character name
#   0  Madam President        None  2016          Samar],
#  ['Neva',
#                title series name  year character name
#   0  Magazine Issues        None  2016    Mrs. Peters],
#  ['Nichol',
#                            title series name  year character name
#   0  Seventeen Collected Solo 62        None  2013           None],
#  ['Nienke',
#            title series name  year character name
#   0  Criss Cross        None  2010          Annie],
#  ['Nikia',
#       title series name  year character name
#   0  Latria        None  2013           None],
#  ['Nikki',
#                     title series name  year character name
#   0  Straight Edge Kegger        None  2016  Belly Slapper],
#  ['Nina',
#                    title          series name  year character name
#   0  �rhundredets vidner  De f�rste teenagere  1998        Herself],
#  ['Norma (I)',
#                                   title                            series name  \
#   0  The Time with Matthew & Randy Show  Sacramento, California: Part 2 (#6.2)
#
#      year character name
#   0  2008        Herself  ],
#  ['Norma (II)',
#      title series name  year character name
#   0  Rajni        None  2015           None],
#  ['Omonigho',
#                        title                                  series name  year  \
#   0  On the Scene Web Series  You Ain't Called, Texted, Nothing... (#3.3)  2015
#
#     character name
#   0        Herself  ],
#  ['Paula',
#                                    title series name  year character name
#   0  Satanico Pandemonium: La Sexorcista        None  1975           None],
#  ['Peggy',
#                     title series name  year character name
#   0  Welcome to Slab City        None  2012        Herself],
#  ['Per (II)',
#                     title series name  year character name
#   0  Die Tote von Amelung        None  1995      Constanze],
#  ['Pernill',
#          title                    series name  year character name
#   0  Bryggeren  12. afsnit, 1884-1887 (#1.12)  1996      Fru K�hle],
#  ['Pia',
#                  title series name  year character name
#   0  Four Wise Monkeys        None  2016    Shawn's Mom],
#  ['Poonam',
#           title series name  year character name
#   0  Dream Lock        None  2016          Maria],
#  ['Puta',
#                                                 title series name  year  \
#   0  Prof. F. Stein oder Ich baue mir meine Traumfrau        None  2006
#
#     character name
#   0           None  ],
#  ['Rachel',
#                                         title series name  year character name
#   0  Lightspeed University: Cheerleader Power        None  2005           None],
#  ['Reem',
#                                      title series name  year  \
#   0  Paranorma There Is Always a Dark Side        None  2011
#
#                                  character name
#   0  One eyed girl in the Surreal World Segment  ],
#  ['Regina',
#             title series name  year character name
#   0  All Suspects        None  2013       Victoria],
#  ['Regina Seeman',
#                     title series name  year character name
#   0  Vacaciones de terror        None  1988         Ni�a 1],
#  ['Renee',
#               title series name  year character name
#   0  Sierra Spirits        None  2009           Inga],
#  ['Rita',
#         title series name  year character name
#   0  Mesh Ana        None  2016         (2016)],
#  ['Sam',
#               title                series name  year character name
#   0  Family Affairs  Linda Lays a Ghost (#1.6)  1949         Marion],
#  ['Samantha',
#             title  series name  year character name
#   0  Plumper Pass  Boob Bumpin  2006           None],
#  ['Samia',
#                title series name  year character name
#   0  Hanan Wa Haneen      (#1.1)  2007          Marwa],
#  ['Sandra Spencer',
#      title series name  year character name
#   0  Ropes        None  2006           Wife],
#  ['Sarah',
#             title series name  year character name
#   0  Cruel Summer        None  2012       Princess],
#  ['Selina',
#                    title series name  year character name
#   0  XConfessions Vol. 1        None  2013           None],
#  ['Shacetta',
#                title series name  year character name
#   0  South of Sanity        None  2016    Frita Clark],
#  ['Sharon',
#                    title                      series name  year  \
#   0  American Experience  Malcolm X: Make It Plain (#6.5)  1988
#
#                 character name
#   0  Herself - Nation of Islam  ],
#  ['Slave',
#              title       series name  year character name
#   0  House of Gord  Orgasming Cocoon  2001           None],
#  ['Sofi',
#          title series name  year character name
#   0  Even More        None  2010        Herself],
#  ['Solana',
#             title series name  year character name
#   0  Best Present        None  2017        Herself],
#  ['Sonia',
#            title series name  year character name
#   0  After Maiko        None  2015  Sophia Martin],
#  ['Stefanie Oxmann Mcgaha',
#                    title series name  year character name
#   0  Night of the Demons        None  2009     Goth raver],
#  ['Steff',
#                    title series name  year character name
#   0  Night of the Demons        None  2009     Goth raver],
#  ['Stephanie',
#         title series name  year character name
#   0  Oakville        None  2013         Shauna],
#  ['Suilma',
#          title series name  year character name
#   0  Amor-Love        None  2002          Zaida],
#  ['Susan',
#                            title                     series name  year  \
#   0  The Kids of Degrassi Street  Cookie Goes to Hospital (#1.2)  1979
#
#     character name
#   0    Nurse Trish  ],
#  ['Suzanna',
#       title series name  year character name
#   0  Lamina        None  2015           None],
#  ['Suzanne',
#          title series name  year character name
#   0  Bloggerne        None  2014        Herself],
#  ['Swan',
#        title series name  year character name
#   0  Menatel        None  2015           None],
#  ['S�lan',
#                              title series name  year         character name
#   0  D�rt duvar arasi kapanmaz ki!        None  2015  (segment "D� r e...")],
#  ['Tammy',
#                title series name  year character name
#   0  Same Difference        None  2015           None],
#  ['Tatiana',
#                                                  title series name  year  \
#   0  How to Dance Through Time, Vol III: The Majest...        None  2003
#
#     character name
#   0        Herself  ],
#  ['The',
#             title series name  year character name
#   0  Kid Millions        None  1934     Show Girls],
#  ['The Pack',
#         title series name  year           character name
#   0  The Hour     (#7.89)  2004  Themselves - Performers],
#  ['Theresa',
#                                           title series name  year character name
#   0  American Soundtrack: Rhythm, Love and Soul        None  2003        Herself],
#  ['Thi',
#                    title series name  year character name
#   0  Military Punishment        None  2003           None],
#  ['Thit',
#             title series name  year  character name
#   0  Voksenf�lden        None  2013  Herself - Thit],
#  ['Tone Damli',
#                                 title        series name  year character name
#   0  Idol - Jakten p� en superstjerne  Topp 50 #5 (#3.6)  2003        Herself],
#  ['Toni',
#                     title series name  year character name
#   0  Welcome to Slab City        None  2012        Herself],
#  ['Tracy',
#           title                                     series name  year  \
#   0  Casting Qs  An Interview with Tracy 'Twinkie' Byrd (#2.14)  2010
#
#     character name
#   0        Herself  ],
#  ['Tyfany',
#                              title series name  year character name
#   0  Big Ass She-Male Road Trip 12        None  2006           None],
#  ['Tymisha',
#                      title series name  year character name
#   0  Blood of the Tribades        None  2016  The Great One],
#  ['Ulia',
#              title series name  year character name
#   0  Between Women      (#2.4)  2011   Brooke Scott],
#  ['Vanda',
#             title series name  year character name
#   0  Boots Camp 1        None  2007           None],
#  ['Vanessa',
#                                     title series name  year character name
#   0  Private Auditions 2: Sex Auditions 5        None  2007           None],
#  ['Venomous',
#      title series name  year  character name
#   0  Mouth        None  2007  News Anchor #1],
#  ['Virgina',
#                                                  title series name  year  \
#   0  Broads & Bombers; a Wartime Experiment in Manp...        None  2016
#
#     character name
#   0        Herself  ],
#  ['Yani',
#       title series name  year character name
#   0  Pensia        None  2015        Herself],
#  ['Yasmine',
#               title series name  year character name
#   0  Ik Hartje Oost        None  2014          Sarah],
#  ['Yvonne',
#                     title series name  year character name
#   0  Girls of Foxy Lady 4        None  1989           None],
#  ['Zoe',
#                        title series name  year character name
#   0  Littie Red White & Blue        None  2009           None]]

# %%
mut_name_rols = pd.DataFrame(data=list_name_rols, columns=['name', 'rols'])
mut_name_rols
# Out:
#               name                                               rols
# 0                           title series name  year character name...
# 1         $haniqua              title             series name  yea...
# 2         & Ashour       title   series name  year        characte...
# 3        & Company                        title series name  year ...
# 4    &Aacutelvarez       title series name  year character name
# 0 ...
# ..             ...                                                ...
# 323        Virgina                                                ...
# 324           Yani      title series name  year character name
# 0  ...
# 325        Yasmine              title series name  year character ...
# 326         Yvonne                    title series name  year char...
# 327            Zoe                       title series name  year c...
#
# [328 rows x 2 columns]

# %%
mut_name_rols.loc[1]['rols']
# Out:
#             title             series name  year       character name
# 0  Please Like Me  All You Can Eat (#1.4)  2013  $haniqua the Rabbit

# %%
mut_name_rols.head(100).to_csv('/Users/fox/Library/CloudStorage/OneDrive-PetertheGreatSt.PetersburgPolytechnicalUniversity/СПБПУ/3 курс/6 семестр/СУБД/资料/DataSet/df_all.csv')

# %%
mut_name_rols.head(100).to_json('/Users/fox/Library/CloudStorage/OneDrive-PetertheGreatSt.PetersburgPolytechnicalUniversity/СПБПУ/3 курс/6 семестр/СУБД/资料/DataSet/df_all.json',
    orient='table',
    index=False)
